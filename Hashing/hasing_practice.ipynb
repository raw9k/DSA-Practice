# %%
arr = [5,6,7,8,7,6,0,8,2,3,4,4,2,3]
tem ={}

for i in range(len(arr)):
    if arr[i] in tem:
        tem[arr[i]] += 1
        
    else:
        tem[arr[i]] = 1
        
print(tem)
print(tem[6])
# Dict add any key value if it not present in it, no need to write additional code to add things in dict
# Out:
# {5: 1, 6: 2, 7: 2, 8: 2, 0: 1, 2: 2, 3: 2, 4: 2}
# 2

# %%
"""
You're given an array (arr)
Return the frequency of element x in the given array
"""
arr = [5,6,7,8,7,6,0,8,2,3,4,4,2,3]
class Solution:
    def findFrequency(self, arr, x):
        temp = {}
        for i in range(0,len(arr)):
            if arr[i] in temp:
                temp[arr[i]] += 1
            else:
                temp[arr[i]] = 1
        if x not in arr:
            return 0
        else:
            return temp[x]       
                
output = Solution()
output.findFrequency(arr, 3)
# Out:
# 2

# %%
# N is array that only contains interger from 1 to 10 and M is an array which can have any int. Print How many number of times M's element comes in N
# Using Dict
n = [1,2,3,5,8,6,9,10]
m=[10,11,1,2,4,7]
c ={}
for i in range(len(n)):
    if n[i] in c:
        c[n[i]] += 1
    else:
        c[n[i]] = 1
for i in m:
    if i<1 or i>10:
        print(i,":",0)
    elif i not in c:
        print(i,":",0)
    else:
        print(i,":",c[i])
# Out:
# 10 : 1
# 11 : 0
# 1 : 1
# 2 : 1
# 4 : 0
# 7 : 0

# %%
# N is array that only contains interger from 1 to 10 and M is an array which can have any int. Print How many number of times M's element comes in N
# Brute Force
n = [1,2,3,5,8,6,9,10]
m=[10,11,1,2,4,7]

for i in m:
    c =0
    for j in n:
        if i==j:
            c +=1
        
    print(f"{i} : {c}")
# Out:
# 10 : 1
# 11 : 0
# 1 : 1
# 2 : 1
# 4 : 0
# 7 : 0

# %%
#Using Hashing

n = [1,2,3,5,4,9,6,9,8,5]
m =[10,22,2,3,5,9,11]
hash =[0]*(len(n)+1)
for i in n:
    hash[i] +=1
for i in m:
    if i<1 or i>10:
        print(f"{i} : {0}")
    else:
        print(f"{i} : {hash[i]}")
# Out:
# 10 : 0
# 22 : 0
# 2 : 1
# 3 : 1
# 5 : 2
# 9 : 2
# 11 : 0

# %%
# Same as above but just for string
s ="abcasonjsdcdiuvbcdnwlsldcxfsdcvx"
q =["a","d","l","b","s"]

hash = [0]*26

for i in s:
    asci_val = ord(i)
    index = asci_val-97
    hash[index] += 1
    
for i in q:
    asci_val = ord(i)
    index = asci_val-97
    print(f"{i} : {hash[index]}")
# Out:
# a : 2
# d : 5
# l : 2
# b : 2
# s : 4

# %%
"""
LINK: https://www.geeksforgeeks.org/problems/frequency-of-array-elements-1587115620/0
You are given an array arr[] containing positive integers. The elements in the array arr[] range from  1 to n (where n is the size of the array), and some numbers may be repeated or absent. Your have to count the frequency of all numbers in the range 1 to n and return an array of size n such that result[i] represents the frequency of the number i (1-based indexing).

Examples:

Input: arr[] = [2, 3, 2, 3, 5]
Output: [0, 2, 2, 0, 1]
Explanation: We have: 1 occurring 0 times, 2 occurring 2 times, 3 occurring 2 times, 4 occurring 0 times, and 5 occurring 1 time.
Input: arr[] = [3, 3, 3, 3]
Output: [0, 0, 4, 0]
Explanation: We have: 1 occurring 0 times, 2 occurring 0 times, 3 occurring 4 times, and 4 occurring 0 times.
Input: arr[] = [1]
Output: [1]
Explanation: We have: 1 occurring 1 time, and there are no other numbers between 1 and the size of the array.
Constraints:
1 ≤ arr.size() ≤ 106
1 ≤ arr[i] ≤ arr.size()
"""


class Solution:
    def frequencyCount(self, arr):
        hash = [0]*len(arr)
        for i in arr:
            hash[i-1] +=1
            
        return hash
arr = [2,3,2,3,5]
out= Solution()
out.frequencyCount(arr)
# Out:
# [0, 2, 2, 0, 1]
